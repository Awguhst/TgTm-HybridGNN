# %% [markdown]
# ## Library Imports and Dependencies

# %%
# Regular EDA (exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sns
import warnings
import rdkit
import mols2grid
import joblib
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import rdmolops
from rdkit.Chem import Descriptors, AllChem, rdMolDescriptors, rdCoordGen
from rdkit.ML.Descriptors import MoleculeDescriptors
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG=True
# %matplotlib inline 

# ML models
import torch
from torch.nn import Linear, Dropout
import torch.nn as nn
import torch.optim as optim
import torch_geometric
from torch.optim.lr_scheduler import StepLR
from torch_geometric.data import Data, Dataset
from torch_geometric.nn import GCNConv, TopKPooling, global_max_pool, global_mean_pool
from torch_geometric.nn import GINConv, GATConv, GraphConv
from torch_geometric.nn import GlobalAttention
from torch_geometric.loader import DataLoader
from torch.utils.data import random_split
from torch_geometric.utils import to_networkx
from torch_geometric.utils import from_smiles
from torch_geometric.nn import AttentiveFP
import torch.nn.functional as F

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score, mean_absolute_error, mean_squared_error

# %%
# Set the seed value
random_seed = 50

# Ensure reproducibility across PyTorch (CPU & GPU)
torch.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed)

# Ensure reproducibility for NumPy
np.random.seed(random_seed)

# Ensure deterministic behavior in PyTorch operations
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
df = pd.read_csv('polymer_tg_tm.csv')
df.shape
# Out:
# (1563, 3)

# %%
df
# Out:
#                                                  SMILES    Tg     Tm
# 0                                                   *C* -54.0  131.0
# 1                                               *CC(*)C  -3.0  164.0
# 2                                              *CC(*)CC -24.1  115.5
# 3                                             *CC(*)CCC -37.0   80.0
# 4                                           *CC(*)C(C)C  60.0  306.0
# ...                                                 ...   ...    ...
# 1558             *CC(*)(F)C(=O)OCC(F)(F)C(F)(F)C(F)(F)F  75.0  187.0
# 1559      *CC(*)(F)C(=O)OCC(F)(F)C(F)(F)C(F)(F)C(F)(F)F  63.0  171.0
# 1560     *CC(*)(F)C(=O)OCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)F   6.0   91.0
# 1561  *CC(*)(F)C(=O)OCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)C...  53.0  104.0
# 1562  *CC(*)(F)C(=O)OCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)C...  53.0  157.0
#
# [1563 rows x 3 columns]

# %% [markdown]
# ## Data preprocessing

# %%
def calculate_descriptors(mol):
    if mol is None:
        return torch.zeros(1, 25, dtype=torch.float)

    descriptors = [
        Descriptors.MolWt(mol),
        Descriptors.Chi0(mol),
        Descriptors.TPSA(mol),
        Descriptors.NumHDonors(mol),
        Descriptors.NumRotatableBonds(mol),
        Descriptors.MolLogP(mol),
        Descriptors.NumHAcceptors(mol),
        Descriptors.FractionCSP3(mol),
        Descriptors.RingCount(mol),
        Descriptors.HeavyAtomCount(mol),
        Descriptors.NHOHCount(mol),
        Descriptors.NOCount(mol),

        # Additional ones
        Descriptors.NumAliphaticRings(mol),
        Descriptors.NumAromaticRings(mol),
        Descriptors.BalabanJ(mol),
        Descriptors.HallKierAlpha(mol),
        Descriptors.MolMR(mol),
        Descriptors.LabuteASA(mol),

        # VSA-based descriptors (pick a few representative ones)
        Descriptors.PEOE_VSA1(mol),
        Descriptors.PEOE_VSA2(mol),
        Descriptors.SMR_VSA1(mol),
        Descriptors.SMR_VSA2(mol),
        Descriptors.EState_VSA1(mol),
        Descriptors.EState_VSA2(mol),
        Descriptors.VSA_EState1(mol)
    ]

    return torch.tensor(descriptors, dtype=torch.float).view(1, -1)

# %%
descriptor_list = []

for smile in df['SMILES']:
    mol = Chem.MolFromSmiles(smile)
    desc = calculate_descriptors(mol)
    descriptor_list.append(desc)

# Convert to (N, 12) array
descriptor_matrix = torch.cat(descriptor_list, dim=0).numpy()

# Standardize
scaler = StandardScaler()
desc_scaled = scaler.fit_transform(descriptor_matrix)

# %%
pca = PCA(n_components=12)  # You can tune this
desc_pca = pca.fit_transform(desc_scaled)

# %%
# Initialize an empty list to store the graphs
graph_list = []

for i, smile in enumerate(df['SMILES']):
    g = from_smiles(smile)
    g.x = g.x.float()

    # PCA-transformed descriptor
    desc_tensor = torch.tensor(desc_pca[i], dtype=torch.float).view(1, -1)
    
    y = torch.tensor([df['Tg'][i], df['Tm'][i]], dtype=torch.float).view(1, -1)

    g.y = y
    g.descriptors = desc_tensor
    graph_list.append(g)

# %%
 graph_list[0]
# Out:
# Data(x=[3, 9], edge_index=[2, 4], edge_attr=[4, 3], smiles='*C*', y=[1, 2], descriptors=[1, 12])

# %% [markdown]
# ## GNN Definition and Model Training

# %%
# Define the ratio for splitting the dataset (80% for training, 20% for validation)
train_ratio = 0.80

# Calculate the total number of samples in the dataset
dataset_size = len(graph_list)

# Calculate the number of samples for the training and validation sets
train_size = int(train_ratio * dataset_size)
val_size = dataset_size - train_size

# Set a random seed for reproducibility
random_seed = 66
generator = torch.Generator().manual_seed(random_seed)

# Split the dataset into training and validation subsets
train_dataset, val_dataset = random_split(graph_list, [train_size, val_size], generator=generator)

# %%
# Create the DataLoaders for the train and val sets
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16)

# %%
class HybridGNN(nn.Module):
    def __init__(self, hidden_channels, descriptor_size, dropout_rate):
        super(HybridGNN, self).__init__()

        # GINConv (good for strong structure modeling)
        self.conv1 = GINConv(Linear(9, hidden_channels))  # Assuming 9 input node features

        # GATConv (learns importance weights for neighbors)
        self.conv2 = GATConv(hidden_channels, hidden_channels, heads=2, concat=False)

        # GraphConv (stable refinement)
        self.conv3 = GraphConv(hidden_channels, hidden_channels)

        # GELU and dropout
        self.gelu = nn.GELU()
        self.dropout = Dropout(p=dropout_rate)

        # Combine graph embedding + descriptor
        combined_size = hidden_channels * 2 + descriptor_size

        self.shared_fc = nn.Sequential(
            Linear(combined_size, 128),
            nn.GELU(),
            Dropout(dropout_rate)
        )

        self.tg_head = nn.Sequential(
            Linear(128, 64),
            nn.GELU(),
            Dropout(dropout_rate),
            Linear(64, 1)
        )

        self.tm_head = nn.Sequential(
            Linear(128, 64),
            nn.GELU(),
            Dropout(dropout_rate),
            Linear(64, 1)
        )

    def forward(self, x, edge_index, batch_index, descriptors):
        h = self.gelu(self.conv1(x, edge_index))
        h = self.gelu(self.conv2(h, edge_index))
        h = self.gelu(self.conv3(h, edge_index))

        h = torch.cat([
            global_max_pool(h, batch_index),
            global_mean_pool(h, batch_index)
        ], dim=1)

        combined = torch.cat([h, descriptors], dim=1)
        shared_features = self.shared_fc(combined)

        tg_out = self.tg_head(shared_features)
        tm_out = self.tm_head(shared_features)
        return torch.cat([tg_out, tm_out], dim=1), shared_features

# %%
# Set up the device (GPU if available, otherwise CPU) and initialize the model and optimizer
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Initialize the model with specified parameters and move it to the appropriate device
model = HybridGNN(hidden_channels=128, descriptor_size=12, dropout_rate=0.6).to(device)

# Set up the NAdam optimizer with learning rate and weight decay for regularization
optimizer = torch.optim.NAdam(model.parameters(), lr=0.0008, weight_decay=0.0)

# Set up a Scheduler
scheduler = StepLR(optimizer, step_size=15, gamma=0.75)

# %%
def train(loader):
    total_loss = total_samples = 0

    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()

        # Model predictions: shape (batch_size, 2) -> [Tg, Tm]
        out, _ = model(data.x, data.edge_index, data.batch, data.descriptors)

        # MSE loss for both targets
        loss = F.mse_loss(out, data.y)

        loss.backward()
        optimizer.step()

        total_loss += float(loss) * data.num_graphs
        total_samples += data.num_graphs

    return np.sqrt(total_loss / total_samples)

# %%
@torch.no_grad()  # Disable gradient tracking for validation (improves speed and reduces memory)
def val(loader):
    model.eval()  # Set the model to evaluation mode (e.g., disables dropout)
    
    total_samples = total_loss = 0 

    # Iterate through the validation dataset
    for data in loader:
        data = data.to(device)  # Move data to the appropriate device (CPU or GPU)

        # Forward pass through the model
        out, _ = model(data.x, data.edge_index, data.batch, data.descriptors)

        # Compute mean squared error (MSE) for the batch
        loss = F.mse_loss(out, data.y)  # By default, reduction='mean'

        # Accumulate the weighted loss (loss * number of graphs in batch)
        total_loss += float(loss) * data.num_graphs
        total_samples += data.num_graphs

    # Compute and return root mean squared error (RMSE)
    return np.sqrt(total_loss / total_samples)

# %%
warnings.filterwarnings("ignore", category=UserWarning)


# Initialize lists to store training and val scores (RMSE values)
score_train = []
score_val = []

# Set the number of epochs for training
epochs = 200

# Loop over each epoch for training
for epoch in range(epochs):
    
    # Train the model and get the training RMSE
    train_rmse = train(train_loader)

    # Adjust learning rate
    scheduler.step()

    # Validate the model and get the val RMSE
    val_rmse = val(val_loader)

    # Append the training RMSE and val RMSE to their respective lists
    score_train.append(train_rmse)
    score_val.append(val_rmse)

    # Print the progress of the training process (epoch number, train loss, val loss)
    print(f'Epoch: {epoch+1}/{epochs} | Train Loss: {train_rmse:.4f}, '
          f'Validation Loss: {val_rmse:.4f}')
# Out:
# Epoch: 1/200 | Train Loss: 133.0116, Validation Loss: 92.8734
# Epoch: 2/200 | Train Loss: 86.5593, Validation Loss: 87.0509
# Epoch: 3/200 | Train Loss: 81.5019, Validation Loss: 109.8140
# Epoch: 4/200 | Train Loss: 78.7862, Validation Loss: 75.9900
# Epoch: 5/200 | Train Loss: 75.4295, Validation Loss: 75.2940
# Epoch: 6/200 | Train Loss: 74.9245, Validation Loss: 72.9196
# Epoch: 7/200 | Train Loss: 72.8060, Validation Loss: 77.3861
# Epoch: 8/200 | Train Loss: 72.1929, Validation Loss: 100.8872
# Epoch: 9/200 | Train Loss: 71.3245, Validation Loss: 71.1953
# Epoch: 10/200 | Train Loss: 70.4931, Validation Loss: 74.3370
# Epoch: 11/200 | Train Loss: 70.3494, Validation Loss: 70.0986
# Epoch: 12/200 | Train Loss: 68.7486, Validation Loss: 78.4789
# Epoch: 13/200 | Train Loss: 68.5702, Validation Loss: 76.0616
# Epoch: 14/200 | Train Loss: 69.5679, Validation Loss: 80.8685
# Epoch: 15/200 | Train Loss: 68.0009, Validation Loss: 73.9632
# Epoch: 16/200 | Train Loss: 67.1664, Validation Loss: 73.7577
# Epoch: 17/200 | Train Loss: 66.2836, Validation Loss: 69.2635
# Epoch: 18/200 | Train Loss: 65.2356, Validation Loss: 81.4597
# Epoch: 19/200 | Train Loss: 66.0108, Validation Loss: 76.0419
# Epoch: 20/200 | Train Loss: 64.0462, Validation Loss: 116.1953
# Epoch: 21/200 | Train Loss: 64.8170, Validation Loss: 84.6474
# Epoch: 22/200 | Train Loss: 63.4738, Validation Loss: 65.3914
# Epoch: 23/200 | Train Loss: 63.1337, Validation Loss: 123.2392
# Epoch: 24/200 | Train Loss: 64.2754, Validation Loss: 65.8707
# Epoch: 25/200 | Train Loss: 61.4013, Validation Loss: 61.8501
# Epoch: 26/200 | Train Loss: 60.9705, Validation Loss: 65.1428
# Epoch: 27/200 | Train Loss: 60.0168, Validation Loss: 60.4616
# Epoch: 28/200 | Train Loss: 60.0500, Validation Loss: 61.9059
# Epoch: 29/200 | Train Loss: 59.7441, Validation Loss: 78.9699
# Epoch: 30/200 | Train Loss: 59.8200, Validation Loss: 61.7575
# Epoch: 31/200 | Train Loss: 57.8561, Validation Loss: 76.3465
# Epoch: 32/200 | Train Loss: 57.6113, Validation Loss: 78.5583
# Epoch: 33/200 | Train Loss: 57.1560, Validation Loss: 63.5724
# Epoch: 34/200 | Train Loss: 56.5976, Validation Loss: 59.3098
# Epoch: 35/200 | Train Loss: 56.5017, Validation Loss: 60.1906
# Epoch: 36/200 | Train Loss: 55.9610, Validation Loss: 57.0458
# Epoch: 37/200 | Train Loss: 55.1467, Validation Loss: 54.9349
# Epoch: 38/200 | Train Loss: 54.8213, Validation Loss: 53.9583
# Epoch: 39/200 | Train Loss: 54.2719, Validation Loss: 60.1816
# Epoch: 40/200 | Train Loss: 55.5767, Validation Loss: 54.8349
# Epoch: 41/200 | Train Loss: 54.1102, Validation Loss: 53.3467
# Epoch: 42/200 | Train Loss: 53.9014, Validation Loss: 54.6208
# Epoch: 43/200 | Train Loss: 53.6450, Validation Loss: 60.8125
# Epoch: 44/200 | Train Loss: 53.3141, Validation Loss: 55.1238
# Epoch: 45/200 | Train Loss: 53.1168, Validation Loss: 57.4233
# Epoch: 46/200 | Train Loss: 52.6948, Validation Loss: 52.7196
# Epoch: 47/200 | Train Loss: 52.0950, Validation Loss: 57.5829
# Epoch: 48/200 | Train Loss: 52.1361, Validation Loss: 58.0970
# Epoch: 49/200 | Train Loss: 52.2919, Validation Loss: 53.0123
# Epoch: 50/200 | Train Loss: 51.8038, Validation Loss: 53.4258
# Epoch: 51/200 | Train Loss: 51.4638, Validation Loss: 57.6080
# Epoch: 52/200 | Train Loss: 51.5739, Validation Loss: 52.9444
# Epoch: 53/200 | Train Loss: 51.2201, Validation Loss: 55.6160
# Epoch: 54/200 | Train Loss: 51.0608, Validation Loss: 58.8925
# Epoch: 55/200 | Train Loss: 51.1385, Validation Loss: 52.1236
# Epoch: 56/200 | Train Loss: 50.9818, Validation Loss: 51.5866
# Epoch: 57/200 | Train Loss: 50.6059, Validation Loss: 52.1466
# Epoch: 58/200 | Train Loss: 50.7481, Validation Loss: 53.4368
# Epoch: 59/200 | Train Loss: 50.4569, Validation Loss: 51.9231
# Epoch: 60/200 | Train Loss: 49.9486, Validation Loss: 53.8978
# Epoch: 61/200 | Train Loss: 49.7471, Validation Loss: 54.6215
# Epoch: 62/200 | Train Loss: 49.4060, Validation Loss: 50.8475
# Epoch: 63/200 | Train Loss: 49.1144, Validation Loss: 51.0670
# Epoch: 64/200 | Train Loss: 49.1127, Validation Loss: 65.6990
# Epoch: 65/200 | Train Loss: 50.2015, Validation Loss: 51.7598
# Epoch: 66/200 | Train Loss: 48.7034, Validation Loss: 51.2530
# Epoch: 67/200 | Train Loss: 48.8347, Validation Loss: 50.5126
# Epoch: 68/200 | Train Loss: 48.9083, Validation Loss: 51.3089
# Epoch: 69/200 | Train Loss: 48.7460, Validation Loss: 52.0564
# Epoch: 70/200 | Train Loss: 48.6784, Validation Loss: 51.2968
# Epoch: 71/200 | Train Loss: 48.2596, Validation Loss: 50.3406
# Epoch: 72/200 | Train Loss: 48.0786, Validation Loss: 51.8287
# Epoch: 73/200 | Train Loss: 47.9946, Validation Loss: 53.6708
# Epoch: 74/200 | Train Loss: 48.1962, Validation Loss: 49.9240
# Epoch: 75/200 | Train Loss: 47.9124, Validation Loss: 51.2020
# Epoch: 76/200 | Train Loss: 47.5544, Validation Loss: 51.3863
# Epoch: 77/200 | Train Loss: 47.3470, Validation Loss: 50.4541
# Epoch: 78/200 | Train Loss: 47.4301, Validation Loss: 52.7512
# Epoch: 79/200 | Train Loss: 47.3899, Validation Loss: 49.5448
# Epoch: 80/200 | Train Loss: 47.0972, Validation Loss: 49.7092
# Epoch: 81/200 | Train Loss: 47.0320, Validation Loss: 51.9976
# Epoch: 82/200 | Train Loss: 47.1362, Validation Loss: 49.7768
# Epoch: 83/200 | Train Loss: 46.8610, Validation Loss: 51.2658
# Epoch: 84/200 | Train Loss: 46.9483, Validation Loss: 52.0050
# Epoch: 85/200 | Train Loss: 46.8843, Validation Loss: 62.2990
# Epoch: 86/200 | Train Loss: 47.6425, Validation Loss: 50.3295
# Epoch: 87/200 | Train Loss: 46.5812, Validation Loss: 49.2386
# Epoch: 88/200 | Train Loss: 46.2638, Validation Loss: 51.3335
# Epoch: 89/200 | Train Loss: 46.3340, Validation Loss: 52.0896
# Epoch: 90/200 | Train Loss: 46.3480, Validation Loss: 49.3910
# Epoch: 91/200 | Train Loss: 46.0793, Validation Loss: 49.8889
# Epoch: 92/200 | Train Loss: 45.7712, Validation Loss: 49.6543
# Epoch: 93/200 | Train Loss: 45.7368, Validation Loss: 49.4392
# Epoch: 94/200 | Train Loss: 45.7226, Validation Loss: 52.2101
# Epoch: 95/200 | Train Loss: 45.7046, Validation Loss: 53.0100
# Epoch: 96/200 | Train Loss: 45.7893, Validation Loss: 49.5586
# Epoch: 97/200 | Train Loss: 45.4061, Validation Loss: 48.8821
# Epoch: 98/200 | Train Loss: 45.4993, Validation Loss: 50.4424
# Epoch: 99/200 | Train Loss: 45.6622, Validation Loss: 51.6796
# Epoch: 100/200 | Train Loss: 45.3887, Validation Loss: 49.0335
# Epoch: 101/200 | Train Loss: 45.3782, Validation Loss: 49.1023
# Epoch: 102/200 | Train Loss: 45.2414, Validation Loss: 50.5320
# Epoch: 103/200 | Train Loss: 45.2399, Validation Loss: 49.1893
# Epoch: 104/200 | Train Loss: 45.0812, Validation Loss: 51.6174
# Epoch: 105/200 | Train Loss: 44.8875, Validation Loss: 50.4897
# Epoch: 106/200 | Train Loss: 44.8693, Validation Loss: 49.1021
# Epoch: 107/200 | Train Loss: 44.7088, Validation Loss: 50.8267
# Epoch: 108/200 | Train Loss: 44.6994, Validation Loss: 49.2908
# Epoch: 109/200 | Train Loss: 44.6049, Validation Loss: 49.5140
# Epoch: 110/200 | Train Loss: 44.3087, Validation Loss: 49.3583
# Epoch: 111/200 | Train Loss: 44.6078, Validation Loss: 48.9137
# Epoch: 112/200 | Train Loss: 44.4959, Validation Loss: 49.0064
# Epoch: 113/200 | Train Loss: 44.4258, Validation Loss: 49.7123
# Epoch: 114/200 | Train Loss: 44.3828, Validation Loss: 50.1276
# Epoch: 115/200 | Train Loss: 44.4280, Validation Loss: 48.7715
# Epoch: 116/200 | Train Loss: 44.3303, Validation Loss: 49.0440
# Epoch: 117/200 | Train Loss: 44.2301, Validation Loss: 49.0850
# Epoch: 118/200 | Train Loss: 44.2754, Validation Loss: 48.9334
# Epoch: 119/200 | Train Loss: 44.0720, Validation Loss: 50.0346
# Epoch: 120/200 | Train Loss: 44.0666, Validation Loss: 49.1544
# Epoch: 121/200 | Train Loss: 43.9313, Validation Loss: 48.8216
# Epoch: 122/200 | Train Loss: 43.8063, Validation Loss: 48.9550
# Epoch: 123/200 | Train Loss: 43.6607, Validation Loss: 48.8346
# Epoch: 124/200 | Train Loss: 43.7541, Validation Loss: 49.1059
# Epoch: 125/200 | Train Loss: 43.6387, Validation Loss: 48.4368
# Epoch: 126/200 | Train Loss: 43.6631, Validation Loss: 48.4942
# Epoch: 127/200 | Train Loss: 43.5952, Validation Loss: 48.4287
# Epoch: 128/200 | Train Loss: 43.5235, Validation Loss: 48.5020
# Epoch: 129/200 | Train Loss: 43.6731, Validation Loss: 48.6812
# Epoch: 130/200 | Train Loss: 43.5764, Validation Loss: 48.7195
# Epoch: 131/200 | Train Loss: 43.6824, Validation Loss: 49.6253
# Epoch: 132/200 | Train Loss: 43.5605, Validation Loss: 48.8358
# Epoch: 133/200 | Train Loss: 43.5405, Validation Loss: 49.3968
# Epoch: 134/200 | Train Loss: 43.4394, Validation Loss: 48.8855
# Epoch: 135/200 | Train Loss: 43.3299, Validation Loss: 48.6818
# Epoch: 136/200 | Train Loss: 43.1645, Validation Loss: 48.6699
# Epoch: 137/200 | Train Loss: 43.2119, Validation Loss: 48.6626
# Epoch: 138/200 | Train Loss: 43.1333, Validation Loss: 48.4579
# Epoch: 139/200 | Train Loss: 42.9315, Validation Loss: 48.1845
# Epoch: 140/200 | Train Loss: 43.0738, Validation Loss: 49.3359
# Epoch: 141/200 | Train Loss: 43.0656, Validation Loss: 48.1289
# Epoch: 142/200 | Train Loss: 43.1282, Validation Loss: 48.6368
# Epoch: 143/200 | Train Loss: 42.9446, Validation Loss: 48.4972
# Epoch: 144/200 | Train Loss: 42.9512, Validation Loss: 48.2425
# Epoch: 145/200 | Train Loss: 42.8994, Validation Loss: 48.0060
# Epoch: 146/200 | Train Loss: 42.9658, Validation Loss: 49.8769
# Epoch: 147/200 | Train Loss: 43.3030, Validation Loss: 48.1197
# Epoch: 148/200 | Train Loss: 42.8252, Validation Loss: 48.3296
# Epoch: 149/200 | Train Loss: 42.7828, Validation Loss: 48.2677
# Epoch: 150/200 | Train Loss: 42.7099, Validation Loss: 48.4864
# Epoch: 151/200 | Train Loss: 42.6409, Validation Loss: 48.1943
# Epoch: 152/200 | Train Loss: 42.5488, Validation Loss: 48.5628
# Epoch: 153/200 | Train Loss: 42.8410, Validation Loss: 48.2452
# Epoch: 154/200 | Train Loss: 42.5110, Validation Loss: 48.6120
# Epoch: 155/200 | Train Loss: 42.6560, Validation Loss: 48.1789
# Epoch: 156/200 | Train Loss: 42.5238, Validation Loss: 48.1503
# Epoch: 157/200 | Train Loss: 42.3586, Validation Loss: 48.4244
# Epoch: 158/200 | Train Loss: 42.4294, Validation Loss: 48.3456
# Epoch: 159/200 | Train Loss: 42.3755, Validation Loss: 49.3644
# Epoch: 160/200 | Train Loss: 42.8059, Validation Loss: 47.8477
# Epoch: 161/200 | Train Loss: 42.3376, Validation Loss: 48.0118
# Epoch: 162/200 | Train Loss: 42.3982, Validation Loss: 48.0621
# Epoch: 163/200 | Train Loss: 42.3697, Validation Loss: 48.1084
# Epoch: 164/200 | Train Loss: 42.2708, Validation Loss: 48.3244
# Epoch: 165/200 | Train Loss: 42.2436, Validation Loss: 47.9752
# Epoch: 166/200 | Train Loss: 42.1701, Validation Loss: 47.9736
# Epoch: 167/200 | Train Loss: 42.1957, Validation Loss: 48.1051
# Epoch: 168/200 | Train Loss: 42.2093, Validation Loss: 48.0829
# Epoch: 169/200 | Train Loss: 42.1614, Validation Loss: 48.0278
# Epoch: 170/200 | Train Loss: 42.0846, Validation Loss: 48.1579
# Epoch: 171/200 | Train Loss: 42.2222, Validation Loss: 48.1320
# Epoch: 172/200 | Train Loss: 42.0516, Validation Loss: 48.0155
# Epoch: 173/200 | Train Loss: 42.0277, Validation Loss: 48.6411
# Epoch: 174/200 | Train Loss: 42.1077, Validation Loss: 48.4999
# Epoch: 175/200 | Train Loss: 41.9805, Validation Loss: 48.6913
# Epoch: 176/200 | Train Loss: 42.0618, Validation Loss: 48.0268
# Epoch: 177/200 | Train Loss: 42.0239, Validation Loss: 48.0512
# Epoch: 178/200 | Train Loss: 41.9871, Validation Loss: 48.0677
# Epoch: 179/200 | Train Loss: 42.1066, Validation Loss: 48.0155
# Epoch: 180/200 | Train Loss: 41.8298, Validation Loss: 48.9075
# Epoch: 181/200 | Train Loss: 41.9521, Validation Loss: 48.0623
# Epoch: 182/200 | Train Loss: 41.8247, Validation Loss: 47.9349
# Epoch: 183/200 | Train Loss: 41.8313, Validation Loss: 48.1103
# Epoch: 184/200 | Train Loss: 41.8296, Validation Loss: 48.0231
# Epoch: 185/200 | Train Loss: 41.8258, Validation Loss: 47.9768
# Epoch: 186/200 | Train Loss: 41.7710, Validation Loss: 48.0618
# Epoch: 187/200 | Train Loss: 41.8289, Validation Loss: 48.3493
# Epoch: 188/200 | Train Loss: 41.7815, Validation Loss: 47.9856
# Epoch: 189/200 | Train Loss: 41.8185, Validation Loss: 48.2941
# Epoch: 190/200 | Train Loss: 41.8743, Validation Loss: 48.0440
# Epoch: 191/200 | Train Loss: 41.6924, Validation Loss: 47.9092
# Epoch: 192/200 | Train Loss: 41.8017, Validation Loss: 47.9691
# Epoch: 193/200 | Train Loss: 41.7105, Validation Loss: 48.0413
# Epoch: 194/200 | Train Loss: 41.6498, Validation Loss: 48.0812
# Epoch: 195/200 | Train Loss: 41.7149, Validation Loss: 48.2471
# Epoch: 196/200 | Train Loss: 41.6163, Validation Loss: 47.9852
# Epoch: 197/200 | Train Loss: 41.5334, Validation Loss: 48.0434
# Epoch: 198/200 | Train Loss: 41.6719, Validation Loss: 47.9713
# Epoch: 199/200 | Train Loss: 41.6185, Validation Loss: 48.1577
# Epoch: 200/200 | Train Loss: 41.6644, Validation Loss: 47.9215

# %%
#Choose a style for the plot
plt.style.use("default")

# Create figure
plt.figure(figsize=(10, 7))

# Plot training and validation losses with improved styling
plt.plot(range(epochs), score_train, label='Training Loss', 
         color='#ffda06', linestyle='-', linewidth=2.2, alpha=1)

plt.plot(range(epochs), score_val, label='Validation Loss', 
         color='red', linestyle='--', linewidth=2, alpha=1)

# Labels and title with a bold but clean look
plt.xlabel('Epochs', fontsize=14, fontweight='bold', color='#333333')
plt.ylabel('RMSE', fontsize=14, fontweight='bold', color='#333333')
plt.title('Training and Validation Loss', fontsize=17, fontweight='bold', color='#222222')

# Improve grid visibility but keep it subtle
plt.grid(True, linestyle='--', linewidth=0.7, alpha=0.6)

# Improve legend (slightly larger, no border)
plt.legend(loc='upper right', fontsize=13, frameon=False)

# Adjust layout for a clean look
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model Evaluation & Visualization

# %%
@torch.no_grad()  # Disable gradient computation for evaluation
def eval(loader):
    preds = []  # Store model predictions
    trues = []  # Store true target values
    smi = []    # Store SMILES strings
    model.eval()  # Set model to evaluation mode
    
    for data in loader:
        data = data.to(device)  # Move data to the correct device (GPU/CPU)
        
        # Get model predictions
        out, _ = model(data.x, data.edge_index, data.batch, data.descriptors) 
        
        # Append predictions and true labels
        preds.append(out.cpu())
        trues.append(data.y.cpu())
        
        # Append SMILES strings
        smi.extend(data.smiles)  # extend, not append, since it's a list of strings
    
    # Convert to NumPy arrays
    preds = torch.cat(preds, dim=0).numpy()
    trues = torch.cat(trues, dim=0).numpy()
    
    # Build DataFrame with separate columns for each target
    results = pd.DataFrame({
        'smiles': smi,
        'Tg': trues[:, 0],
        'Tm': trues[:, 1],
        'Tg pred': preds[:, 0],
        'Tm pred': preds[:, 1],
    })
    
    return results

# %%
val_res = eval(val_loader)

# %%
val_res
# Out:
#                                                 smiles     Tg          Tm  \
# 0          *CCCCCCCCCCCNC(=O)CCCCCCCCCCCCCCCCCCC(=O)N*   29.0  167.000000
# 1    *Oc1cc(OC(=O)c2ccc(OC)cc2)c(OC(=O)CCCC(*)=O)cc...   88.0  220.000000
# 2    *CCCCCCCCCCCC(=O)Oc1ccc(OC(=O)c2ccc3c(c2)C(=O)...   58.0  172.500000
# 3        *CC(*)(F)C(=O)OCC(F)(F)C(F)(F)C(F)(F)C(F)(F)F   63.0  171.000000
# 4    *Oc1ccc(C(c2ccc(OC(=O)c3ccc(C(c4ccc(C(*)=O)cc4...  135.0  181.000000
# ..                                                 ...    ...         ...
# 308           *CCCCCCCCCCOC(=O)c1ccc2cc(C(=O)O*)ccc2c1   50.5  144.000000
# 309                          *CCCOC(=O)NCCCCCCNC(=O)O*   55.0  168.000000
# 310                                            *CCCCO*  -80.0   37.299999
# 311  *CCCNC(=O)C(NC(=O)C(Cc1ccccc1)NC(=O)CCCCCCCCC(...   66.0  238.000000
# 312    *CCCCCCCCCCCCNC(=O)c1ccc(C(=O)N*)c(Oc2ccccc2)c1   75.0  144.000000
#
#         Tg pred     Tm pred
# 0     24.428629  155.045868
# 1     90.238464  227.937592
# 2     70.396294  195.027710
# 3     71.170212  158.622025
# 4    193.768478  262.113495
# ..          ...         ...
# 308   42.384201  144.231674
# 309   46.410664  174.096436
# 310  -50.569214   81.529373
# 311   77.721443  207.532913
# 312   71.548050  181.453613
#
# [313 rows x 5 columns]

# %%
def evaluate_preds(y_true, y_preds):
    # Calculate metrics
    metrics = {"R2": r2_score(y_true, y_preds),
               "RMSE": np.sqrt(mean_squared_error(y_true, y_preds)),
               "MAE": mean_absolute_error(y_true, y_preds)}

    # Print the metrics
    for metric, value in metrics.items():
        print(f"{metric}: {value:.3f}")

    # Return rounded metrics
    return {metric: round(value, 3) for metric, value in metrics.items()}

# %%
evaluate_preds(val_res['Tg'], val_res['Tg pred']);
# Out:
# R2: 0.847
# RMSE: 36.444
# MAE: 26.062

# %%
evaluate_preds(val_res['Tm'], val_res['Tm pred']);
# Out:
# R2: 0.753
# RMSE: 57.138
# MAE: 41.627

# %%
def run_cross_validation(graph_list, train_fn, val_fn, eval_fn,
                         k_folds, n_epochs, batch_size, seed):

    warnings.filterwarnings("ignore", category=UserWarning)
    torch.manual_seed(seed)
    np.random.seed(seed)

    graph_list = list(graph_list)
    kf = KFold(n_splits=k_folds, shuffle=True, random_state=seed)

    tg_rmse_list, tm_rmse_list = [], []
    tg_r2_list, tm_r2_list = [], []

    print(f"\n=== Starting {k_folds}-Fold Cross-Validation ===")

    for fold, (train_idx, val_idx) in enumerate(kf.split(graph_list)):
        print(f"\n--- Fold {fold + 1}/{k_folds} ---")

        train_dataset = [graph_list[i] for i in train_idx]
        val_dataset = [graph_list[i] for i in val_idx]

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size)

        # Define global variables for compatibility with your existing train/val/eval
        global model, optimizer, scheduler, device

        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = HybridGNN(hidden_channels=128, descriptor_size=12, dropout_rate=0.6).to(device)
        optimizer = torch.optim.NAdam(model.parameters(), lr=0.0008, weight_decay=0.0)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.75)

        for epoch in range(n_epochs):
            train_rmse = train_fn(train_loader)
            scheduler.step()
            val_rmse = val_fn(val_loader)

        fold_df = eval_fn(val_loader)
        tg_rmse = mean_squared_error(fold_df['Tg'], fold_df['Tg pred']) ** 0.5
        tm_rmse = mean_squared_error(fold_df['Tm'], fold_df['Tm pred']) ** 0.5
        tg_r2 = r2_score(fold_df['Tg'], fold_df['Tg pred'])
        tm_r2 = r2_score(fold_df['Tm'], fold_df['Tm pred'])

        tg_rmse_list.append(tg_rmse)
        tm_rmse_list.append(tm_rmse)
        tg_r2_list.append(tg_r2)
        tm_r2_list.append(tm_r2)

        print(f"Fold {fold+1} Results:")
        print(f"  Tg R²: {tg_r2:.4f} | RMSE: {tg_rmse:.4f}")
        print(f"  Tm R²: {tm_r2:.4f} | RMSE: {tm_rmse:.4f}")

    def summary(metric_list, name):
        mean = np.mean(metric_list)
        std = np.std(metric_list)
        return f"{name}: {mean:.4f} ± {std:.4f}"

    print("\n=== Cross-Validation Summary ===")
    print(summary(tg_r2_list, "Tg R²"))
    print(summary(tm_r2_list, "Tm R²"))
    print(summary(tg_rmse_list, "Tg RMSE"))
    print(summary(tm_rmse_list, "Tm RMSE"))

# %%
run_cross_validation(
    graph_list=graph_list,
    train_fn=train,
    val_fn=val,
    eval_fn=eval,
    k_folds=5,
    n_epochs=200,
    batch_size=16,
    seed=50
)
# Out:
# === Starting 5-Fold Cross-Validation ===
#
# --- Fold 1/5 ---
# Fold 1 Results:
#   Tg R²: 0.7911 | RMSE: 40.0967
#   Tm R²: 0.7059 | RMSE: 62.3268
#
# --- Fold 2/5 ---
# Fold 2 Results:
#   Tg R²: 0.8175 | RMSE: 42.5733
#   Tm R²: 0.7213 | RMSE: 62.1650
#
# --- Fold 3/5 ---
# Fold 3 Results:
#   Tg R²: 0.8114 | RMSE: 38.5224
#   Tm R²: 0.6725 | RMSE: 63.6082
#
# --- Fold 4/5 ---
# Fold 4 Results:
#   Tg R²: 0.8291 | RMSE: 35.4619
#   Tm R²: 0.6996 | RMSE: 59.5599
#
# --- Fold 5/5 ---
# Fold 5 Results:
#   Tg R²: 0.7846 | RMSE: 42.7318
#   Tm R²: 0.6594 | RMSE: 67.0755
#
# === Cross-Validation Summary ===
# Tg R²: 0.8067 ± 0.0166
# Tm R²: 0.6918 ± 0.0226
# Tg RMSE: 39.8772 ± 2.7128
# Tm RMSE: 62.9471 ± 2.4475

# %%
# Compute R² score and RMSE
r2 = r2_score(val_res['Tg'], val_res['Tg pred'])
rmse = np.sqrt(mean_squared_error(val_res['Tg'], val_res['Tg pred']))

# Choose a style for the plot
sns.set_style('darkgrid')  # Dark grid background for the plot
sns.set_palette("crest")  # Set the color palette for the plot

# Set figure size
plt.figure(figsize=(10, 8))

# Scatter plot: Actual vs Predicted values
plt.scatter(val_res['Tg'], val_res['Tg pred'], color='#415eff', alpha=0.8, edgecolors='black', s=80)

# Plot the line of perfect prediction (45-degree line)
plt.plot([min(val_res['Tg']), max(val_res['Tg'])], 
         [min(val_res['Tg']), max(val_res['Tg'])], 
         color='#ff0a3f', linestyle='--', lw=3.8, label="Perfect Fit (y=x)")  

# Create legend text
legend_text = f'R² Score: {r2:.2f}\nRMSE: {rmse:.2f}'

# Add a professional-looking legend in the **top-left corner**
legend = plt.legend([legend_text], loc="upper left", fontsize=13.5, 
                    frameon=True, edgecolor="black", facecolor="white", 
                    borderpad=0.5)

# Increase border thickness
legend.get_frame().set_linewidth(1.3)

# Title and labels
plt.title('Real vs Predicted Tg', fontsize=18, fontweight='bold', color='#333333')
plt.xlabel('Real Tg (°C)', fontsize=15, fontweight='bold', color='#333333')
plt.ylabel('Predicted Tg (°C)', fontsize=15, fontweight='bold', color='#333333')

# Display grid and plot
plt.grid(True)
plt.show()

# %%
# Compute R² score and RMSE
r2 = r2_score(val_res['Tm'], val_res['Tm pred'])
rmse = np.sqrt(mean_squared_error(val_res['Tm'], val_res['Tm pred']))

# Choose a style for the plot
sns.set_style('darkgrid')  # Dark grid background for the plot
sns.set_palette("crest")  # Set the color palette for the plot

# Set figure size
plt.figure(figsize=(10, 8))

# Scatter plot: Actual vs Predicted values
plt.scatter(val_res['Tm'], val_res['Tm pred'], color='#415eff', alpha=0.8, edgecolors='black', s=80)

# Plot the line of perfect prediction (45-degree line)
plt.plot([min(val_res['Tm']), max(val_res['Tm'])], 
         [min(val_res['Tm']), max(val_res['Tm'])], 
         color='#ff0a3f', linestyle='--', lw=3.8, label="Perfect Fit (y=x)")  

# Create legend text
legend_text = f'R² Score: {r2:.2f}\nRMSE: {rmse:.2f}'

# Add a professional-looking legend in the **top-left corner**
legend = plt.legend([legend_text], loc="upper left", fontsize=13.5, 
                    frameon=True, edgecolor="black", facecolor="white", 
                    borderpad=0.5)

# Increase border thickness
legend.get_frame().set_linewidth(1.3)

# Title and labels
plt.title('Real vs Predicted Tm', fontsize=18, fontweight='bold', color='#333333')
plt.xlabel('Real Tm (°C)', fontsize=15, fontweight='bold', color='#333333')
plt.ylabel('Predicted Tm (°C)', fontsize=15, fontweight='bold', color='#333333')

# Display grid and plot
plt.grid(True)
plt.show()

# %%
torch.save(model.state_dict(), "hybrid_gnn.pt")

# %%
joblib.dump(scaler, "scaler.pkl")
joblib.dump(pca, "pca.pkl")
# Out:
# ['pca.pkl']
